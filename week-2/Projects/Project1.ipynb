# %% [markdown]
# PROJECT1 A PSEUDOCODE
# START
# INPUT ITEM NAME
# INPUT ITEM AMOUNT
# SET ITEM_NAME TO [ITEM,ITEM,ITEM]
# SET ITEM_PRICES TO { ITEMX : PRICE
#                 ITEMX : PRICE}
# SET ITEM_TOTALS TO []
# FOR ITEM IN ITEM_NAME
# IF ITEM_NAME IS IN ITEM_PRICES
#     SET ITEM_TOTAL TO ITEM_PRICES["ITEMX"] * AMOUNT
#     ADD ITEM_TOTAL TO ITEM_TOTALS
# ELSE
#     BREAK
#
# SET TOTAL_PRICE TO SUM(ITEM_TOTALS)
#
# PRINT(YOU CHECKED OUT THE FOLLOWING)
# PRINT(ITEM_NAMES)
# PRINT(FOR TOTAL PRICES)
# PRINT(ITEM_TOTALS)
# PRINT(TOTAL_PRICE)
#
# END

# %% [markdown]
# PROJECT 1 A flowchart
# ![Screenshot 2026-03-11 151534.png](attachment:d0a87c90-b382-4e9c-898a-e3aec31c81cb.png)

# %%
PROJECT 1 B FLOWCHART

# %% [markdown]
# ![PROJECT1B.drawio.png](attachment:61620977-a871-4da4-afb1-d56ebd91bb7f.png)

# %% [markdown]
# PROJECT 1 C
# INPUT NAME1
# INPUT AGE1
# INPUT NAME2
# INPUT AGE2
#
# SET AGEHOLDER TO AGE1
# SET AGE1 TO AGE2
# SET AGE2 TO AGEHOLDER
#
# PRINT(NAME1 IS AGE1 YEARS OLD)
# PRINT(NAME2 IS AGE2 YEARS OLD)
