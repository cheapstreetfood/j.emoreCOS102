# %%
str1 = "Hi my name is Funke. I'm a string"
str2 = "Wazaaaaap. Call me Tunks. Im also a string"

#displaying str1 and its type
print(str1)
print(type(str1))

#displaying str2 and its type
print(str2)
print(type(str2))
