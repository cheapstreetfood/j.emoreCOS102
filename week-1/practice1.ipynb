# %%
# Integer number
num = 1005
print(num)
print(f"Data Type of variable num is{type(num)}")

# float number
fnum = 684.45
print(fnum)
print(f"Data Type of variable fnum is{type(num)}")

# complex number
cnum = 3 - 4j
print(f"Data type of variable cnum is {type(num)}")
# Out:
# 1005
# Data Type of variable num is<class 'int'>
# 684.45
# Data Type of variable fnum is<class 'int'>
# Data type of variable cnum is <class 'int'>
